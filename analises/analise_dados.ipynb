# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
dados = 'dados_ficha_a_desafio.csv'

df = pd.read_csv(dados)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 35 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   id_paciente                            100000 non-null  object
#  1   sexo                                   100000 non-null  object
#  2   obito                                  100000 non-null  object
#  3   bairro                                 100000 non-null  object
#  4   raca_cor                               100000 non-null  object
#  5   ocupacao                               100000 non-null  object
#  6   religiao                               100000 non-null  object
#  7   luz_eletrica                           100000 non-null  object
#  8   data_cadastro                          100000 non-null  object
#  9   escolaridade                           100000 non-null  object
# ...

# %%
df
# Out:
#                                 id_paciente    sexo  obito           bairro  \
# 0      cd6daa6e-038d-4952-af29-579e62e07f97    male      0  Parada de Lucas
# 1      ad6cecb2-3a44-49ab-b2f3-6f9ffc2e2ec7    male      0      Cidade Nova
# 2      54e834e7-e722-4daa-8909-cf917a1247e6    male      0       Santa cruz
# 3      c6a71e5e-0933-48d1-9d5a-8f448dc37f71  female  False            Bangu
# 4      d5262a3c-e5d3-4195-a46b-0acd2533e1d6    male      0       Santíssimo
# ...                                     ...     ...    ...              ...
# 99995  9aa08b9f-44f3-417d-bd1d-66288d7beaae  female  False     Rio Comprido
# 99996  1b1f7444-8959-4210-b5de-cdfb9b62eab8  female      0         Realengo
# 99997  2c1d1127-0575-4df1-a879-12734f7cbf39  female      0       Amendoeira
# 99998  6a28a1d0-9d1f-4d66-8f28-759083b91f59  female      0       Santa cruz
# 99999  d582b5c6-06c6-4741-9fcc-ccbc22d43413  female      0     Campo Grande
#
# ...

# %%
# Função para corrigir a codificação, remover espaços e remover aspas, colchetes e caracteres específicos
def corrigir_limpar_e_strip(texto):
    if isinstance(texto, str):
        texto_corrigido = texto.encode('latin1').decode('unicode_escape')
        texto_limpo = texto_corrigido.replace('"', '').replace("'", '').replace('[', '').replace(']', '').strip()
        return texto_limpo
    return texto

df = df.map(corrigir_limpar_e_strip)

df.sample(5)
# Out:
#                                 id_paciente    sexo obito        bairro  \
# 83697  742792b2-9607-409d-839c-61b05a09b931    male     0  Padre Miguel
# 74054  77d27c41-d8f4-4a2c-b912-1c4aa97c73cb  female     0  Higienópolis
# 33862  5ba5323d-0761-470f-a149-5da460774161    male     0   Laranjeiras
# 76924  28b4c568-81eb-46e1-a88b-d698e8f93c1c    male     0         Bangu
# 52680  c669a215-f5dc-44d0-9b8b-ca652b978c79  female     0    Santa cruz
#
#       raca_cor                                     ocupacao  religiao  \
# 83697    Preta                  Agente Comunitário de Saúde     Outra
# 74054  Amarela                                Não se aplica     Outra
# 33862   Branca  Marinheiro de Convés (marítimo e Fluviário)  Católica
# 76924   Branca                                Não se aplica  Católica
# 52680    Preta                 Empregado Doméstico Diarista     Outra
#
#       luz_eletrica            data_cadastro            escolaridade  \
# ...

# %% [markdown]
# - verificação

# %%
colunas = ['sexo', 'obito', 'raca_cor', 'luz_eletrica',	'escolaridade',	'renda_familiar', 'em_situacao_de_rua', 'frequenta_escola',	'meios_transporte', 'doencas_condicoes', 'identidade_genero', 'meios_comunicacao', 'orientacao_sexual', 'possui_plano_saude', 'em_caso_doenca_procura', 'situacao_profissional', 'vulnerabilidade_social', 'data_atualizacao_cadastro',	'familia_beneficiaria_auxilio_brasil', 'crianca_matriculada_creche_pre_escola', 'tipo']

# Verificar valores únicos em cada coluna especificada
for coluna in colunas:
    valores_unicos = df[coluna].unique()
    print(f"Valores únicos na coluna '{coluna}':")
    print(valores_unicos)

# %%
meios_transporte = df['meios_transporte'].unique()

print("meios_transporte:")
meios_transporte

# %% [markdown]
# - Inconsistências no preenchimento

# %%
i_renda = df.query("renda_familiar == 'Manhã' or renda_familiar == 'Internet'")
i_renda
# Out:
#                                 id_paciente    sexo obito bairro raca_cor  \
# 22459  8b5e8f49-66f1-4331-aabb-d781acec803c    male     0   Anil   Branca
# 43594  9027bee5-a5e8-4273-a0fa-396991bf5869  female     0  Irajá    Parda
#
#             ocupacao  religiao luz_eletrica            data_cadastro  \
# 22459       Pedreiro     Outra            1  2021-03-10 00:00:00.000
# 43594  Não se aplica  Católica            0  2023-09-08 10:39:33.707
#
#                  escolaridade nacionalidade renda_familiar data_nascimento  \
# 22459          Médio Completo    Brasileira          Manhã      1974-07-10
# 43594  Fundamental Incompleto    Brasileira       Internet      2005-02-16
#
#       em_situacao_de_rua  frequenta_escola meios_transporte doencas_condicoes  \
# 22459                  0                 0           Ônibus
# 43594                  0                 0           Ônibus       Hipertensão
#
#       identidade_genero meios_comunicacao orientacao_sexual  \
# ...

# %%
id_duplicados = df[df['id_paciente'].duplicated()]
id_duplicados.sample(5)
# Out:
#                                 id_paciente    sexo obito         bairro  \
# 70510  04c57a59-469f-4855-b771-6f81e1b43ed3  female     0          Bangu
# 41125  8135951d-8955-401f-aaef-208475024446    male     0        Inhaúma
# 84199  2d8fa450-d89b-4f97-b520-e7dd27d9dbec    male     0         Centro
# 62805  85d9ea96-d796-4081-b347-3a72f1e1c337  female     0          Bangu
# 44881  e7adaaa4-7e47-4c98-a328-ee703f8d5324    male     0  São Cristovão
#
#       raca_cor               ocupacao      religiao luz_eletrica  \
# 70510    Parda  Vendedor Em Domicílio      Católica            1
# 41125    Parda          Não se aplica      Católica            1
# 84199   Branca          Não se aplica  Sem religião            0
# 62805    Parda          Não se aplica  Sem religião            1
# 44881   Branca               Pedreiro  Sem religião            1
#
#                  data_cadastro            escolaridade nacionalidade  \
# ...

# %%
vulnerabilidade_social = df['vulnerabilidade_social'].unique()

print("vulnerabilidade_social:")
vulnerabilidade_social
# Out:
# vulnerabilidade_social:
# array(['0', '1', 'False', 'True'], dtype=object)

# %% [markdown]
# Obs: a mesma incosistência de preenchimento da coluna 'vulnerabilidade_social' foi observada na colunas 'obito', 'luz_eletrica', 'em_situacao_de_rua', 'possui_plano_de_saude', 'familia_beneficiaria_auxilio_brasil' e 'crianca_matriculada_creche_pre_escola'
